# %%
import json

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data

# %%
def display_users(data):

    print("User Information")
    for user in data["users"]:
        print(f"ID:{user['id']} is {user['name']} and has friends with id{user['friends']} and like pages are {user['liked_pages']}")
    print("\n")

    print("Page Information")
    for page in data["pages"]:
        print(f"Page ID : {page["id"]} and Page Name : {page["name"]}")

# %%
data = load_data("Data.json")
display_users(data)
# Out:
# User Information
# ID:1 is Amit and has friends with id[2, 3] and like pages are [101]
# ID:2 is Priya and has friends with id[1, 4] and like pages are [102]
# ID:3 is Rahul and has friends with id[1] and like pages are [101, 103]
# ID:4 is Sara and has friends with id[2] and like pages are [104]
#
#
# Page Information
# Page ID : 101 and Page Name : Python Developers
# Page ID : 102 and Page Name : Data Science Enthusiasts
# Page ID : 103 and Page Name : AI & ML Community
# Page ID : 104 and Page Name : Web Dev Hub
