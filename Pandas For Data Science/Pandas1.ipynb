# %%
import pandas as pd

# %%
s1 = pd.Series([71,84,56,23,56,98,56])

# %%
type(s1)
# Out:
# pandas.Series

# %%
print(s1)
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
s2 = pd.Series([71,84,56,23,56,98,56],index = ["Krish","Shubham","Anshu","Aman","Atharv","Ram","Sourav"])

# %%
type(s2)
# Out:
# pandas.Series

# %%
print(s2)
# Out:
# Krish      71
# Shubham    84
# Anshu      56
# Aman       23
# Atharv     56
# Ram        98
# Sourav     56
# dtype: int64

# %%
print(s2["Krish"])
# Out:
# 71

# %%
print(s2["Shubham"])
# Out:
# 84

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
d = pd.DataFrame(data)

# %%
d
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
d.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
d.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
