# %%
import pandas as pd

# %%
df = pd.read_csv("data1.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df = df[df["IMDb"]>6.0]

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df.to_csv("data_updated.csv",index=False)

# %%
df1 = pd.read_json("my.json")

# %%
df1
# Out:
#    ID   Name                                Address
# 0   1  Alice   {'city': 'Delhi', 'zipcode': 110001}
# 1   2    Bob  {'city': 'Mumbai', 'zipcode': 400001}

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Actor                 9 non-null      str
#  1   Film                  9 non-null      str
#  2   Year                  9 non-null      int64
#  3   Genre                 9 non-null      str
#  4   BoxOffice(INR Crore)  9 non-null      int64
#  5   IMDb                  9 non-null      float64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 504.0 bytes

# %%
data = [
    {"ID":1,"Name":"Alice","Address":{"city":"Delhi","zipcode":110001}},
    {"ID":2,"Name":"Bob","Address":{"city":"Mumbai","zipcode":400001    }}
]

# %%
df1= pd.json_normalize(data)

# %%
df1
# Out:
#    ID   Name Address.city  Address.zipcode
# 0   1  Alice        Delhi           110001
# 1   2    Bob       Mumbai           400001

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2 non-null      int64
#  1   Name             2 non-null      str
#  2   Address.city     2 non-null      str
#  3   Address.zipcode  2 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 196.0 bytes
