# %%
import json

# %%
def clean_data(data):
    #Remove the users with missing names
    data["users"] = [user for user in data["users"] if user["name"].strip()]

    #Remove the duplicate values
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))

    #Remove the inactive users
    data["users"] = [user for user in data["users"] if ((len(user["friends"])!=0)) or ((len(user["liked_pages"])!=0))]

    #Remove the duplicate pages
    unique_pages={}
    for page in data["pages"]:
        unique_pages[page["id"]] = page
    data["pages"] = list(unique_pages.values())
    
    return data
#load the data
data = json.load(open("Data2.json","r"))
data=clean_data(data)
json.dump(data, open("cleaned_data2.json","w"),indent = 4)
print("data has been cleaned successfully")
# Out:
# data has been cleaned successfully

# %%
data1 = json.load(open("cleaned_data2.json","r"))

# %%
data1['users']
# Out:
# [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#  {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#  {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}]

# %%
data1["pages"]
# Out:
# [{'id': 101, 'name': 'Python Developers'},
#  {'id': 102, 'name': 'Data Science Enthusiasts'},
#  {'id': 103, 'name': 'AI & ML Community'},
#  {'id': 104, 'name': 'Web Dev Hub'},
#  {'id': 104, 'name': 'Web Development'}]
