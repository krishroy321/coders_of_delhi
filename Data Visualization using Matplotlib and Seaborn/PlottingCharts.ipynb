# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])

# %%
years = [1990,1992,1994,1996,1998,2000,2003,2005,2007,2010]
runs = [500,700,1100,1500,1800,1200,1700,1300,900,1500]

# %%
plt.plot(years,runs)

# %%
plt.plot(years,runs)
plt.xlabel('Years')
plt.ylabel('Runs scored')
plt.title("Sachin Tendulkar's Yearly Runs")
# Out:
# Text(0.5, 1.0, "Sachin Tendulkar's Yearly Runs")

# %%
kohli = [0,0,500,800,1100,1300,1500,1800,1900,2100]
sehwag = [0,300,800,1200,1500,1700,1600,1400,1000,0]

plt.plot(years,kohli , label="Virat Kohli")
plt.plot(years,sehwag,label="Virender Sehwag")

plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %%
plt.plot(years,kohli, 'ro--',label="Virat Kohli")
plt.plot(years,sehwag,'g^:',label="Virender Sehwag")
plt.legend()

# %%
plt.plot(years,kohli,color="Purple",linestyle='--',label="kohli")
plt.plot(years,sehwag,color="Red",linestyle='-.',label="sehwag")
plt.plot(years,runs,color="blue",label="Sachin")
plt.tight_layout()
plt.grid(True)
plt.legend()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("ggplot")

# %%
plt.plot(years,kohli,color="Purple",linestyle='--',label="kohli")
plt.plot(years,sehwag,color="Red",linestyle='-.',label="sehwag")
plt.plot(years,runs,color="blue",label="Sachin")
plt.tight_layout()
plt.grid(True)
plt.legend()

# %%
with plt.xkcd():
    plt.plot(years,kohli,color="Purple",linestyle='--',label="kohli")
    plt.plot(years,sehwag,color="Red",linestyle='-.',label="sehwag")
    plt.plot(years,runs,color="blue",label="Sachin")
    plt.tight_layout()
    plt.grid(True)
    plt.legend()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
import numpy as np
for i in range(50):
    plt.plot(np.random.rand(100),linewidth=1)

plt.title("Too much data can be confusing")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_excel("Cricket.xlsx")

# %%
print(df)
# Out:
#     Hypothetical_Runs Unnamed: 1 Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0                 NaN       Year      Kohli  Rohit Sharma     Sehwag
# 1                 NaN       2015       1460          1245        980
# 2                 NaN       2016       1852          1400        870
# 3                 NaN       2017       2005          1560        760
# 4                 NaN       2018       2735          1200        650
# 5                 NaN       2019       1580          1850        540
# 6                 NaN       2020        950          1100          0
# 7                 NaN       2021       1200          1400          0
# 8                 NaN       2022       1620          1650          0
# 9                 NaN       2023       2050          1980          0
# 10                NaN       2024       1780          1500          0

# %%
df.dropna(axis=1,inplace=True)

# %%
df.columns = df.iloc[0]
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 0  Year Kohli Rohit Sharma Sehwag
# 0  2015  1460         1245    980
# 1  2016  1852         1400    870
# 2  2017  2005         1560    760
# 3  2018  2735         1200    650
# 4  2019  1580         1850    540
# 5  2020   950         1100      0
# 6  2021  1200         1400      0
# 7  2022  1620         1650      0
# 8  2023  2050         1980      0
# 9  2024  1780         1500      0

# %%
kohli_runs = df["Kohli"].tolist()
kohli_runs
# Out:
# [1460, 1852, 2005, 2735, 1580, 950, 1200, 1620, 2050, 1780]

# %%
rohit_runs = df["Rohit Sharma"].tolist()
rohit_runs
# Out:
# [1245, 1400, 1560, 1200, 1850, 1100, 1400, 1650, 1980, 1500]

# %%
Sehwag_runs = df["Sehwag"].tolist()
Sehwag_runs
# Out:
# [980, 870, 760, 650, 540, 0, 0, 0, 0, 0]

# %%
year = df["Year"].tolist()
year
# Out:
# [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(year,kohli_runs,color="Red",linestyle="-.")
plt.plot(year,rohit_runs,color="Black",linestyle="-")
plt.plot(year,Sehwag_runs,color="Purple",linestyle="--")
